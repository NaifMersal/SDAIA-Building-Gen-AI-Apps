# %% [markdown]
# # Lab: Hermes Agent — A Guided Tour of the User Surface
#
# **Module 02b — Context Engineering**
#
# ## Objectives
#
# By the end of this lab you will be able to:
#
# 1. **Read** the Hermes Agent documentation as a reference for any production agent runtime.
# 2. **Predict** how Hermes resolves a project's context-file priority and budget.
# 3. **Predict** the outcome of `@`-reference expansions under the documented budget and blocklist rules.
# 4. **Contrast** Hermes's frozen-snapshot memory model with the online memory pipeline you built in Lab 02.
# 5. **Author** a SKILL.md that follows the documented frontmatter and section conventions.
# 6. **Justify** terminal-backend choices against three deployment scenarios.
#
# ## The Story
#
# Sessions 01 and 02 gave you the *shape* of the context problem — sessions, compaction, memory pipelines, and skills as procedural memory. Session 03 walked through Hermes Agent as one shipping answer.
#
# This lab is a **docs-driven literacy exercise**. No `pip install`, no `hermes chat`. You read the same five docs pages you saw in the slides and answer questions that force you to *predict* Hermes behavior from the rules it documents.
#
# The point is not Hermes. The point is the skill of reading an unfamiliar agent runtime quickly enough to make engineering decisions about it.
#
# | Part | Topic |
# |------|-------|
# | 1 | Pin the five docs URLs |
# | 2 | Context Files quiz — priority, budget, scope |
# | 3 | Context References quiz — `@` syntax, budgets, blocklist |
# | 4 | Memory model compare — vs. your Lab 02 pipeline |
# | 5 | SKILL.md authoring — write one for a hypothetical skill |
# | 6 | Tools tradeoff — pick a terminal backend per scenario |
# | 7 | Reflection |
#
# Grading is on your written answers, not on code execution. Most cells are markdown.

# %% [markdown]
# ---
# ## Part 1: Pin the docs
#
# Open all five tabs now. Keep them open for the rest of the lab.
#
# 1. **Context Files** — <https://hermes-agent.nousresearch.com/docs/user-guide/features/context-files>
# 2. **Context References** — <https://hermes-agent.nousresearch.com/docs/user-guide/features/context-references>
# 3. **Memory** — <https://hermes-agent.nousresearch.com/docs/user-guide/features/memory>
# 4. **Skills** — <https://hermes-agent.nousresearch.com/docs/user-guide/features/skills>
# 5. **Tools** — <https://hermes-agent.nousresearch.com/docs/user-guide/features/tools>
#
# > **Heads-up.** The Hermes docs do not carry version numbers. If a rule you read here disagrees with the live page, trust the live page and flag the divergence in your reflection (Part 7).

# %% [markdown]
# ---
# ## Part 2: Context Files quiz
#
# **Read first:** the *Context Files* docs page.
#
# For each scenario below, write **(a)** which file Hermes loads, and **(b)** how its size is handled. One sentence each.
#
# ### Scenario 2.1
# A project has both `AGENTS.md` (5K chars) and `CLAUDE.md` (3K chars) in the repo root.
#
# ### Scenario 2.2
# A project has only `.cursorrules` (8K chars) in the repo root.
#
# ### Scenario 2.3
# A project has `.hermes.md` at 35K chars in the repo root.
#
# ### Scenario 2.4
# A user has `~/.hermes/SOUL.md` (1K chars) but no project file in the working directory.
#
# ### Bonus 2.5
# The agent runs `cd src/api && search_files "..."`. There is no `.hermes.md` in the repo root, but `src/api/AGENTS.md` (2K chars) exists. Does Hermes load it? Why or why not?

# %% [markdown]
# ### Your answers (Part 2)
#
# *Write your answers below. Edit this cell.*
#
# **2.1** —
#
# **2.2** —
#
# **2.3** —
#
# **2.4** —
#
# **2.5** —

# %% [markdown]
# ---
# ## Part 3: Context References quiz
#
# **Read first:** the *Context References* docs page.
#
# For each invocation, predict the outcome. Categories to choose from: **(A) expands cleanly**, **(B) soft-limit warning appended**, **(C) hard-limit refusal**, **(D) blocked path**, **(E) folder cap exceeded**, **(F) git cap exceeded**, **(G) invalid — warning, not failure**.
#
# Assume an empty conversation context (so the only thing competing for budget is the reference itself).
#
# | # | Invocation | Detail | Your call (A–G) |
# |---|---|---|---|
# | 3.1 | `@file:README.md` | README is 2K chars | |
# | 3.2 | `@file:.env` | Located at `$HERMES_HOME/.env` | |
# | 3.3 | `@folder:node_modules` | 18,000 files | |
# | 3.4 | `@git:25` | The repo has 50 commits in main | |
# | 3.5 | `@file:src/main.py:200-100` | Inverted line range, file is 300 lines | |
# | 3.6 | `@url:https://...` | A 600KB HTML page injected into a 200K context window | |
# | 3.7 | `@file:~/.ssh/id_rsa` | Standard SSH key path | |
#
# ### Bonus 3.8
# What design principle do the 25% soft / 50% hard budgets enforce? Write 2–3 sentences. Compare to a system that has *no* budget cap — what failure modes does that system invite?

# %% [markdown]
# ### Your answers (Part 3)
#
# *Fill in the table above. Then answer 3.8 below.*
#
# **3.8** —

# %% [markdown]
# ---
# ## Part 4: Memory model compare
#
# **Read first:** the *Memory* docs page. Then re-open your Lab 02 notebook.
#
# Hermes's built-in memory is *frozen at session start* — the docs say it explicitly: "captured once at session start and never changes mid-session." Your Lab 02 pipeline read, wrote, and retrieved memory **during** a turn.
#
# Write **5–7 sentences** answering all three:
#
# 1. What does each design optimize for? (Hint: think about prefix caching for one, freshness for the other.)
# 2. What does each design give up?
# 3. Name a concrete product scenario where you would pick each. Be specific — "a chatbot" is not specific enough.
#
# ### Bonus 4.b
# The Hermes docs say external memory providers "operate **alongside** built-in memory without replacing it." Why might a designer choose additive providers over replacement? What new failure modes does additive design create?

# %% [markdown]
# ### Your answer (Part 4)
#
# *Edit this cell.*
#
# **4** —
#
# **4.b** —

# %% [markdown]
# ---
# ## Part 5: Author a SKILL.md
#
# **Read first:** the *Skills* docs page.
#
# Write a complete `SKILL.md` for the hypothetical skill below. Use the documented frontmatter fields and the four documented body sections.
#
# **Skill spec:** *"Summarize the staged git diff for a commit message."* The agent should invoke this when the user has staged changes and asks for a commit message, but **not** when the user is asking for a code review or a security audit.
#
# Required:
# - Frontmatter: `name`, `description`, `version`, `platforms`, `requires_toolsets`, `fallback_for_toolsets`.
# - Body sections (in this order): **When to Use**, **Procedure**, **Pitfalls**, **Verification**.
# - The `description` field must be specific enough that the agent picks this skill *only* in the right case — re-read the docs page on description quality.
#
# ### Self-critique (Part 5 follow-up)
# After writing, answer: which one of your **Pitfalls** entries is the one a junior teammate would *not* think of? Why?

# %% [markdown]
# ### Your SKILL.md (Part 5)
#
# *Edit this cell. Keep it as a markdown code block.*
#
# ```markdown
# ---
# name:
# description:
# version:
# platforms:
# requires_toolsets:
# fallback_for_toolsets:
# ---
#
# ## When to Use
#
#
#
# ## Procedure
#
#
#
# ## Pitfalls
#
#
#
# ## Verification
#
# ```
#
# **Self-critique:**

# %% [markdown]
# ---
# ## Part 6: Tools — pick a terminal backend
#
# **Read first:** the *Tools* docs page, especially the terminal-backend section.
#
# Hermes documents six terminal backends: `docker`, `local`, `ssh`, `singularity`, `modal`, `daytona`. For each scenario, pick one and justify in one paragraph.
#
# ### Scenario 6.1 — CI runner
# An agent runs in a GitHub Actions job to triage failing tests. The job has a 6-minute wall-clock budget. The repo's tests need Python 3.11, Postgres 15, and `libxml2-dev`.
#
# ### Scenario 6.2 — Developer laptop
# An engineer runs the agent on their MacBook during pair-debugging sessions. They want the agent to inspect files, run `pytest`, and not require Docker Desktop.
#
# ### Scenario 6.3 — Shared HPC cluster
# A research team runs the agent on a shared SLURM cluster where Docker is not permitted and jobs are submitted to compute nodes via `srun`.
#
# ### Bonus 6.4
# The docs highlight that the Docker backend is *persistent* — "one long-lived container per session, not a fresh container per command." Name one production scenario where persistence is a *liability*, not an asset. Two sentences.

# %% [markdown]
# ### Your answers (Part 6)
#
# *Edit this cell.*
#
# **6.1 (CI runner)** —
#
# **6.2 (Laptop)** —
#
# **6.3 (HPC)** —
#
# **6.4 (Persistence as liability)** —

# %% [markdown]
# ---
# ## Part 7: Reflection
#
# Pick **one** of the five surfaces (Context Files, Context References, Memory, Skills, Tools).
#
# Answer all three in 6–10 sentences total:
#
# 1. **Which surface would you adopt first in your own agent?** Why?
# 2. **Which Hermes design choice in that surface would you change**, and what would you replace it with?
# 3. **What does the Hermes design tell you about an assumption that surface makes** — about users, about workloads, about deployment — that might not hold for your project?

# %% [markdown]
# ### Your reflection (Part 7)
#
# *Edit this cell.*
#
# **Surface chosen:**
#
# **1.**
#
# **2.**
#
# **3.**

# %% [markdown]
# ---
# ## Wrap-up
#
# You have now read one shipping agent's documented user surface end-to-end. The four questions from the Session 03 wrap-up are now yours to apply to any new agent runtime you encounter:
#
# 1. Where do project instructions enter?
# 2. How does the user inject ad-hoc context?
# 3. Where does long-term knowledge live?
# 4. How does the agent acquire new procedures?
#
# Save this notebook. Your answers are the deliverable.
